# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sb 
import numpy as np

# %%
df=pd.read_csv("shopping_trends.csv")

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.isna().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (3900, 19)

# %%
df["Age"].plot(kind="hist")
plt.title("distribution of age")
plt.xlabel("Age")
plt.ylabel("frequency")
plt.show()

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df["Gender"].value_counts().plot(kind="bar")
plt.title("bar plot of gender distribution")
plt.show()

# %%
df.groupby("Category")["Purchase Amount (USD)"].mean().sort_values(ascending=False)
# Out:
# Category
# Footwear       60.255426
# Clothing       60.025331
# Accessories    59.838710
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %%
df.sort_values("Review Rating",ascending=False,inplace=True)

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 776           777   49    Male          Shirt     Clothing
# 1664         1665   19    Male        Handbag  Accessories
# 1277         1278   19    Male         Blouse     Clothing
# 2632         2633   24    Male          Scarf  Accessories
# 965           966   43    Male          Boots     Footwear
# ...           ...  ...     ...            ...          ...
# 1451         1452   54    Male         Jacket    Outerwear
# 3473         3474   63  Female          Dress     Clothing
# 1449         1450   18    Male          Socks     Clothing
# 133           134   52    Male        Sweater     Clothing
# 870           871   66    Male         Hoodie     Clothing
#
#       Purchase Amount (USD)       Location Size     Color  Season  \
# 776                      60        Alabama    M    Maroon  Spring
# 1664                     53      Minnesota    M    Purple  Spring
# ...

# %%
df["Subscription Status"].value_counts().plot(kind="pie")
plt.title("pie chart of subscription status")
plt.show()

# %%
df["Color"].value_counts().head().plot(kind="pie",startangle=180)
plt.show()

# %%
df.plot(x="Previous Purchases",y="Review Rating",kind="scatter",color="red")
plt.title("scatter plot- previous purchase rating")
plt.show()

# %%
df.groupby("Season")["Purchase Amount (USD)"].sum().plot(kind="bar")
plt.title("bar graph- total purchases for a season")
plt.show()

# %%
df.boxplot(column="Purchase Amount (USD)",by="Frequency of Purchases")
plt.xticks(rotation=15)
plt.show()

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df['Preferred Payment Method'].value_counts().reset_index()
# Out:
#   Preferred Payment Method  count
# 0                   PayPal    677
# 1              Credit Card    671
# 2                     Cash    670
# 3               Debit Card    636
# 4                    Venmo    634
# 5            Bank Transfer    612

# %%
pd.pivot_table(df,values='Purchase Amount (USD)',index='Location',columns="Item Purchased",aggfunc="mean").head()
# Out:
# Item Purchased  Backpack       Belt  Blouse      Boots       Coat      Dress  \
# Location
# Alabama             74.0  26.500000    52.0  73.666667  54.500000  55.200000
# Alaska              74.6  76.750000    67.5  56.000000  45.500000  74.500000
# Arizona             48.6  84.500000    61.0        NaN  65.333333  71.000000
# Arkansas            90.0  55.000000    66.0  50.000000  54.250000  62.800000
# California          57.4  61.666667    39.5  62.500000  55.000000  58.428571
#
# Item Purchased     Gloves    Handbag        Hat     Hoodie  ...      Scarf  \
# Location                                                    ...
# Alabama         85.000000  57.666667  76.000000  53.000000  ...  75.333333
# Alaska          66.333333  46.000000  52.666667  56.500000  ...  45.000000
# Arizona         87.000000  58.666667  87.000000  66.666667  ...  53.500000
# Arkansas        64.333333  50.000000  35.000000  55.250000  ...  67.500000
# ...

# %%
df.groupby("Size")["Purchase Amount (USD)"].mean()
# Out:
# Size
# L     58.563153
# M     59.924217
# S     61.037707
# XL    60.090909
# Name: Purchase Amount (USD), dtype: float64

# %%
df.groupby("Payment Method")["Purchase Amount (USD)"].sum()
# Out:
# Payment Method
# Bank Transfer    37123
# Cash             38833
# Credit Card      42567
# Debit Card       37118
# PayPal           37449
# Venmo            39991
# Name: Purchase Amount (USD), dtype: int64

# %%
df.groupby("Color")["Category"].value_counts()
# Out:
# Color   Category
# Beige   Clothing       65
#         Accessories    44
#         Footwear       24
#         Outerwear      14
# Black   Clothing       81
#                        ..
# White   Outerwear      15
# Yellow  Clothing       75
#         Accessories    56
#         Footwear       30
#         Outerwear      13
# Name: count, Length: 100, dtype: int64

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df.groupby("Frequency of Purchases")["Previous Purchases"].mean()
# Out:
# Frequency of Purchases
# Annually          24.561189
# Bi-Weekly         24.787934
# Every 3 Months    24.960616
# Fortnightly       25.271218
# Monthly           25.278481
# Quarterly         26.854352
# Weekly            25.771800
# Name: Previous Purchases, dtype: float64

# %%
df.groupby("Season")["Review Rating"].mean().plot(kind="bar")
plt.show()

# %%
df["Season"].value_counts().plot(kind="line",marker=".")
plt.show()

# %%
df["Category"].value_counts().plot(kind="pie")
plt.show()

# %%
df.boxplot(column="Review Rating",by="Gender")
plt.show()

# %%
df["Purchase Amount (USD)"].plot(kind="hist",bins=10,edgecolor="black")
plt.show()

# %%
df.groupby("Color")["Review Rating"].mean().plot(kind="pie")
plt.show()

# %%
df.groupby("Payment Method")["Purchase Amount (USD)"].sum().plot(kind="pie")
plt.ylabel("")
plt.show()

# %%
df.boxplot(column="Purchase Amount (USD)",by='Frequency of Purchases')
plt.show()

# %%
df.groupby("Season")["Purchase Amount (USD)"].sum().plot(kind="pie")
plt.show()
